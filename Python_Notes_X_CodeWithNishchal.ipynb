# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav3829/Day1/blob/main/Python_Notes_X_CodeWithNishchal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[10,20,40,50,]#list data

b=bytearray(a)

print(type(a),type(b))

print(a)
print()

print(b)
# Out:
# <class 'list'> <class 'bytearray'>
# [10, 20, 40, 50]
#
# bytearray(b'\n\x14(2')

# %%
a=range(1,10)
b=range(20,40)
c=range(20,50)
print(type(a),type(b),type(c))
print(a,b,c)
# Out:
# <class 'range'> <class 'range'> <class 'range'>
# range(1, 10) range(20, 40) range(20, 50)

# %%
import math

radius=5

area=math.pi*radius*radius

print("area of circle :",area)
# Out:
# area of circle : 78.53981633974483

# %%
age=20
print('age:',age)
# Out:
# age: 20

# %%
a=20
b=10
c=a+b
print(c)
# Out:
# 30

# %%
""" used for multi-line text, but technically they create a string"""
print("print text")
# Out:
# print text

# %%
age=int(input("Enter the age"))
if age>=18:
  print("you are eligible to vote")
  print("plese carry your ID")
print("program Finished")
# Out:
# Enter the age19
# you are eligible to vote
# plese carry your ID
# program Finished

# %%
import keyword
print(keyword.kwlist)

print(keyword.iskeyword("class"))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# True

# %%
name="Priya"
age=19

print(f"My namee is {name} and I am {age} year old")
# Out:
# My namee is Priya and I am 19 year old

# %%
print("python","java","C++",sep="|")
# Out:
# python|java|C++

# %%
print("gaurav",end=' ')
print("saurav")
# Out:
# gaurav saurav

# %%
print("A",end="-")
print("B",end="-")
print("C")
# Out:
# A-B-C

# %%
age=int(input("enter the number"))
print(age)
print(type(age))
# Out:
# enter the number32
# 32
# <class 'int'>

# %%
price=float(input("enter the price"))
print("price is :",price)

print(type(price))
# Out:
# enter the price20.5000
# price is : 20.5
# <class 'float'>

# %%
num1=int(input("enter first number:   "))
num2=int(input("enter second number:   "))

result=num1+num2

print("sun is: ",result)
# Out:
# enter first number:   12
# enter second number:   12
# sun is:  24

# %%
num1=input("enter first number:   ")
num2=input("enter second number:   ")

print(num1+num2)
# Out:
# enter first number:   12
# enter second number:   12
# 1212

# %%
student_name=input("enter the name :")

math_marks=int(input("Enter the math marks :"))
science_marks=int(input("Enter the science marks :"))
english_marks=int(input("Enter the english marks :"))

total_marks=math_marks+science_marks+english_marks
average_marks=total_marks/3

print("student name :",student_name)
print("total marks :",total_marks)
print("average marks :",average_marks)
# Out:
# enter the name :GAURAV
# Enter the math marks :100
# Enter the science marks :99
# Enter the english marks :98
# student name : GAURAV
# total marks : 297
# average marks : 99.0

# %%
a="19.0"
print(type(a))
# Out:
# <class 'str'>

# %%
a=None
print(type(a))
# Out:
# <class 'NoneType'>

# %%
x="1"

y=int(x)

print(x)
print(y)

print(type(x))
print(type(y))
# Out:
# 1
# 1
# <class 'str'>
# <class 'int'>

# %%
x=10
y=complex(x)

print(x)
print(y)
# Out:
# 10
# (10+0j)

# %%
print(10//3)
print(10%3)
# Out:
# 3
# 1

# %%
a=20
if 18>=a:
  print("10 is greater than a")
print("a is not greater than 20")
# Out:
# a is not greater than 20

# %%
x=10
x%=5#x=x+5
print(x)
# Out:
# 0

# %%
print(True and False)
print(True and True)

print(True or False)
print(False or False)
# Out:
# False
# True
# True
# False

# %%
print(not True)
# Out:
# False

# %%
text="python"

print("p" in text)
print("py" in text)
print("java" in text)
# Out:
# True
# True
# False

# %%
ext="java"

print("J" not in ext)
print("py" not in ext)
# Out:
# True
# True

# %%
a=5
b=3

print(a&b)
# Out:
# 1

# %%
x=4
print(~x)#~x=-(x+1)
# Out:
# -5

# %%
x=5
print(x<<2)
# Out:
# 20

# %%
x=10
print(x<<2)
# Out:
# 40

# %%
a=input("enter the name :")
a2=a.replace("python","java")
print(a2)
# Out:
# enter the name :this langugre python
# this langugre java

# %%
age=int(input("enter the age"))
if age >=18:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# enter the age14
# not eligible to vote

# %%
mark=int(input("enter the mark"))
pass_gread=True
if mark>=35:
  if pass_gread:
    print("pass")
  else:
    print("fail")
else:
  print("fail")
# Out:
# enter the mark5
# fail

# %%
age=12
status='Adult' if age>=18 else"minar"
print(status)
# Out:
# minar

# %%
word="python"
for letter in word:
  print(letter)
# Out:
# p
# y
# t
# h
# o
# n

# %%
a=int(input("enter the number:"))
for number in range(1,10):
  print(number*a)
# Out:
# enter the number:4
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36

# %%
a=int(input("Enter the number a:"))
b=int(input("enter the number b :"))
number=0  #intial number

while number<=a:
  print(number)
  number+=b
# Out:
# Enter the number a:30
# enter the number b :5
# 0
# 5
# 10
# 15
# 20
# 25
# 30

# %%
a=1      #int(input("Enter the number a:"))
b=10      # int(input("enter the number b :"))
c=4        # int(input("enter the number c: "))
for number in range(a,b):
  if number==c:
    pass

    #number+=1
  print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
a=10
for number in range(1,10):
  if number==10:
    break
  print(number)

else:
  print("loop finished")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# loop finished

# %%
for number in range(1,2):
  for number1 in range(1,3):
    for number2 in range(1,4):
      print(number,number1,number2)
# Out:
# 1 1 1
# 1 1 2
# 1 1 3
# 1 2 1
# 1 2 2
# 1 2 3

# %%
for row in range(2,5):
  print("*"*row)
# Out:
# **
# ***
# ****

# %%
name="python"
for index,value in enumerate(name,start=1):
  print(index,value)
# Out:
# 1 p
# 2 y
# 3 t
# 4 h
# 5 o
# 6 n

# %%
letter="ABC"
numbers="123"
for letter,numbers in zip(letter,numbers):
  print(letter,numbers)
# Out:
# A 1
# B 2
# C 3

# %%
student_name=[12,23,4,54,89]
print(len(student_name))
print(student_name)
# Out:
# 5
# [12, 23, 4, 54, 89]

# %%
student_name=("rahul",12,"ram",23,"suraj",12)
print(type(student_name))
print(student_name)
# Out:
# <class 'tuple'>
# ('rahul', 12, 'ram', 23, 'suraj', 12)

# %%
student={"id":12,"name":"rahul","age":21}
# print(student)
# print()
# print(student.keys())

# print(student.values())

# print(student.items())

# for key,value in student.items():
#   print(key*2,value)
a="id" in student
print(a)
# Out:
# True

# %%
students={
    "student1":{
        "name":"aman",
        "id":12
    },
    "student2":{
        "name":"tushar",
        "age":23
    }
}

print(students)
print(students.keys())
print(students.values())

print(students["student1"]["name"])
print(students["student2"]["age"])
students["student1"]["name"]="ram"
print(students)
# Out:
# {'student1': {'name': 'aman', 'id': 12}, 'student2': {'name': 'tushar', 'age': 23}}
# dict_keys(['student1', 'student2'])
# dict_values([{'name': 'aman', 'id': 12}, {'name': 'tushar', 'age': 23}])
# aman
# 23
# {'student1': {'name': 'ram', 'id': 12}, 'student2': {'name': 'tushar', 'age': 23}}

# %%
numbers=[1,2,3,4,5,6]

squares={number:number*number for number in numbers if number%2==0 }

print(squares)
# Out:
# {2: 4, 4: 16, 6: 36}

# %%
numbers={10,30,50,60,60,40}
numbers1=(numbers.remove(40))
print(numbers)
# Out:
# {50, 10, 60, 30}

# %%
number=(1,2,3,4,5,6,6,6)
squear={number*number for number in number}
print(squear)
# Out:
# {1, 4, 36, 9, 16, 25}

# %%
number=(1,2,3,4,5,6,6,6)
even_num={number for number in number if number%2==0 }
print(even_num)
# Out:
# {2, 4, 6}

# %%
a="banana"
print(a.upper())
# Out:
# BANANA

# %%
def note():
  print("hello,world")
note()
# Out:
# hello,world

# %%
def say_hello():
  print("hello")
say_hello()
# Out:
# hello

# %%
def say(name):
  print("hello",name)
say("aman")
# Out:
# hello aman

# %%
name=input("enter the name: ")
age=int(input("enter the age"))
def stud_info(name,age): #position argument
  print("name :",name)
  print("age :",age)
stud_info(name,age)
# Out:
# enter the name: hhiii
# enter the age56
# name : hhiii
# age : 56

# %%
def add(a,b):

  result=a+b

  return result

ans=add(10,20)
print(ans)
# Out:
# 30

# %%
def add(a,b):
  result=a+b
  print (result)
ans=add(10,20)
# print(ans)
# Out:
# 30

# %%
def calculate(a,b):
  total=a+b
  difference=a-b
  return total,difference
sum_result,diff_result=calculate(10,5)
print(sum_result,diff_result)
# print(diff_result)
# Out:
# 15 5

# %%
def add(a,b):
  print(a+b)
add(10,20)
add(10,b=20)
add(a=10,b=20)
add(b=40,a=30)
# Out:
# 30
# 30
# 30
# 70

# %%
def mul(a,b,c):
  print(a*b*c)
mul(1,2,3)
mul(a=1,c=3,b=2)
# Out:
# 6
# 6

# %%
def say(massege="hello"):
  print("name",massege)
say("aman")
say()
# Out:
# name aman
# name hello

# %%
def add_numbers(*numbers):
  total=0
  for number in numbers:
    total+=number
  return total
print(add_numbers(10,20,40))
# Out:
# 70

# %%
def say():
  name="aman"
  print(name.upper())
say()
# Out:
# AMAN

# %%
def g(y):
  print(x)
  print(x+1)
x=5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
c=lambda a:
c(2)
# Out:
# 4

# %%
c=lambda s:"a" in s
c("helloa")
# Out:
# True

# %%
c=lambda x:"even" if x%2==0 else "odd"
c(10)
# Out:
# 'even'

# %%
a = [1,2,3,4,5,6,7]
list(map(lambda x:"even" if x%2==0 else "odd",a))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd']

# %%
# numbers=[1,2,3,4,5,6]
numbers1=[9,8,7]
c=lambda number: number*number,numbers1
print(list(c))
#print(list(c))
# Out:
# [<function <lambda> at 0x7c66a30f1f80>, [9, 8, 7]]

# %%
numbers=[1,2,3,4,5,6]
even_number=(filter(lambda number:number%2==0,numbers))
print(list(even_number))
# Out:
# [2, 4, 6]

# %%
from functools import reduce
numbers=[1,2,3,4]
total=reduce(lambda a,b:a+b,numbers)
print(total)
# Out:
# 10
